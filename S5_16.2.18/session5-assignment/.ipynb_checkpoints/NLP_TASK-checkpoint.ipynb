# %%
# Run this block to install dependencies [Remember to make the statement true]
if 0 != 1:
    # !pip install pandas
    # !pip install tqdm
    # !pip install scikit-learn
    # !pip install gensim
    # !pip install spacy
    # !python -m spacy download en
    # !pip install numpy
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages
# Requirement already satisfied: python-dateutil>=2 in c:\users\user\anaconda3\lib\site-packages (from pandas)
# Requirement already satisfied: pytz>=2011k in c:\users\user\anaconda3\lib\site-packages (from pandas)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from pandas)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2->pandas)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages
# Requirement already satisfied: gensim in c:\users\user\anaconda3\lib\site-packages
# Requirement already satisfied: six>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from gensim)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\user\anaconda3\lib\site-packages (from gensim)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\user\anaconda3\lib\site-packages (from gensim)
# Requirement already satisfied: smart-open>=1.2.1 in c:\users\user\anaconda3\lib\site-packages (from gensim)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: bz2file in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: boto>=2.32 in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: boto3 in c:\users\user\anaconda3\lib\site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in c:\users\user\anaconda3\lib\site-packages (from boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied: botocore<1.10.0,>=1.9.2 in c:\users\user\anaconda3\lib\site-packages (from boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\user\anaconda3\lib\site-packages (from botocore<1.10.0,>=1.9.2->boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied: docutils>=0.10 in c:\users\user\anaconda3\lib\site-packages (from botocore<1.10.0,>=1.9.2->boto3->smart-open>=1.2.1->gensim)
# Requirement already satisfied: spacy in c:\users\user\anaconda3\lib\site-packages
# Requirement already satisfied: numpy>=1.7 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: cymem<1.32,>=1.30 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Collecting pathlib (from spacy)
# Requirement already satisfied: ujson>=1.35 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: dill<0.3,>=0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: regex==2017.4.5 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: msgpack-python in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: msgpack-numpy==0.4.1 in c:\users\user\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Requirement already satisfied: termcolor in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Requirement already satisfied: pyreadline>=1.7.1 in c:\users\user\anaconda3\lib\site-packages (from dill<0.3,>=0.2->spacy)
# Requirement already satisfied: html5lib in c:\users\user\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
# Requirement already satisfied: spacy>=2.0.0a18 in c:\users\user\anaconda3\lib\site-packages (from en-core-web-sm==2.0.0)
# Requirement already satisfied: numpy>=1.7 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: cymem<1.32,>=1.30 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: pathlib in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: ujson>=1.35 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: dill<0.3,>=0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: regex==2017.4.5 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: msgpack-python in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: msgpack-numpy==0.4.1 in c:\users\user\anaconda3\lib\site-packages (from spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: termcolor in c:\users\user\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: pyreadline>=1.7.1 in c:\users\user\anaconda3\lib\site-packages (from dill<0.3,>=0.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: html5lib in c:\users\user\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy>=2.0.0a18->en-core-web-sm==2.0.0)
# Installing collected packages: en-core-web-sm
#   Running setup.py install for en-core-web-sm: started
#     Running setup.py install for en-core-web-sm: finished with status 'done'
# Successfully installed en-core-web-sm-2.0.0
#
#     Error: Couldn't link model to 'en'
#     Creating a symlink in spacy/data failed. Make sure you have the required
#     permissions and try re-running the command as admin, or use a
#     virtualenv. You can still import the model as a module and call its
#     load() method, or create the symlink manually.
#
#     C:\Users\user\Anaconda3\lib\site-packages\en_core_web_sm -->
#     C:\Users\user\Anaconda3\lib\site-packages\spacy\data\en
#
#
#     Download successful
#     Creating a shortcut link for 'en' didn't work (maybe you don't have
#     admin permissions?), but you can still load the model via its full
#     package name:
#
#     nlp = spacy.load('en_core_web_sm')
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages

# %%
import pandas as pd
import spacy
import pickle
from tqdm import tqdm
from gensim.corpora import Dictionary
from sklearn.utils import shuffle
from collections import defaultdict
import numpy as np

nlp = spacy.load('en_core_web_sm')
DATA_LIMIT = 1000

df = pd.read_csv('./imdb_master.csv', encoding='latin1')
df_neg = df[df['label'] == 'neg']
df_pos = df[df['label'] == 'pos']
df = pd.concat((df_pos[:DATA_LIMIT], df_neg[:DATA_LIMIT]))

def process_text(input_string, return_string=False, stem=False):
    text = nlp(u'' + input_string)
    if stem == True:
        text = [tok.lemma_ for tok in text if (tok.is_alpha and not tok.is_stop)]
    else:
        text = [tok.lower_ for tok in text if (tok.is_alpha and not tok.is_stop)]
    if return_string == True:
        return " ".join(text)
    return text
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
df.head()
# Out:
#        Unnamed: 0  type                                             review  \
# 12500       12500  test  I went and saw this movie last night after bei...
# 12501       12501  test  Actor turned director Bill Paxton follows up h...
# 12502       12502  test  As a recreational golfer with some knowledge o...
# 12503       12503  test  I saw this film in a sneak preview, and it is ...
# 12504       12504  test  Bill Paxton has taken the true story of the 19...
#
#       label         file
# 12500   pos     0_10.txt
# 12501   pos  10000_7.txt
# 12502   pos  10001_9.txt
# 12503   pos  10002_8.txt
# 12504   pos  10003_8.txt

# %%
# Make this statement true to run from scratch [It takes time to process the text]
if 1 != 0:
    wordlist = []
    for i in tqdm(range(df.shape[0])):
        wordlist.append(process_text(df['review'].iloc[i]))
        
    with open('vocabulary.txt', 'wb') as vocabulary:
        pickle.dump(wordlist, vocabulary)
    vocabulary.close()
# Out:
# 100%|██████████████████████████████████████████████████████████| 2000/2000 [02:12<00:00, 15.12it/s]

# %%
# Load vocabulary
wordlist = []
with open('vocabulary.txt', 'rb') as vocabulary:
    wordlist = pickle.load(vocabulary)

# %%
len(wordlist[0])
# Out:
# 69

# %%
# Keeping track of frequency of a single token
frequency = defaultdict(int)
for text in wordlist:
    for token in text:
        frequency[token] += 1
        
# Apply Threshold to limit the vocabulary size, discarding the tokens which appeard number of times below the threshold limit 
FREQ_THRESHOLD = 5

thresholded_wordlist =  [[token for token in text if frequency[token] > FREQ_THRESHOLD]
          for text in wordlist]

# Create Dictionary based on the word list
dictionary = Dictionary(thresholded_wordlist)

# Number of tokens
print("Number of Tokens - {}".format(len(dictionary)))
# Out:
# Number of Tokens - 5464

# %%
list(dictionary.iteritems())
# Out:
# [(0, 'able'),
#  (1, 'admit'),
#  (2, 'ben'),
#  (3, 'character'),
#  (4, 'comedy'),
#  (5, 'crying'),
#  (6, 'desperately'),
#  (7, 'emotions'),
#  (8, 'entire'),
#  (9, 'exactly'),
#  (10, 'friends'),
#  (11, 'good'),
#  (12, 'great'),
#  (13, 'grown'),
#  (14, 'half'),
#  (15, 'i'),
#  (16, 'jake'),
#  (17, 'judge'),
#  (18, 'kevin'),
#  (19, 'knew'),
#  (20, 'laughter'),
#  (21, 'let'),
#  (22, 'men'),
#  (23, 'moved'),
#  (24, 'movie'),
#  (25, 'night'),
#  (26, 'overcome'),
#  (27, 'played'),
#  (28, 'saw'),
#  (29, 'second'),
#  (30, 'sign'),
#  (31, 'sold'),
#  (32, 'suggest'),
#  (33, 'tears'),
#  (34, 'the'),
#  (35, 'theater'),
#  (36, 'this'),
#  (37, 'toy'),
#  (38, 'trying'),
#  (39, 'went'),
#  (40, 'while'),
#  (41, 'women'),
#  (42, 'wrong'),
#  (43, 'action'),
#  (44, 'actor'),
#  (45, 'add'),
#  (46, 'alive'),
#  (47, 'american'),
#  (48, 'animated'),
#  (49, 'atmosphere'),
#  (50, 'audience'),
#  (51, 'average'),
#  (52, 'background'),
#  (53, 'based'),
#  (54, 'beginning'),
#  (55, 'better'),
#  (56, 'bill'),
#  (57, 'black'),
#  (58, 'boring'),
#  (59, 'british'),
#  (60, 'brought'),
#  (61, 'caddy'),
#  (62, 'camera'),
#  (63, 'child'),
#  (64, 'compelling'),
#  (65, 'costume'),
#  (66, 'course'),
#  (67, 'creating'),
#  (68, 'creative'),
#  (69, 'credit'),
#  (70, 'credits'),
#  (71, 'day'),
#  (72, 'debut'),
#  (73, 'department'),
#  (74, 'depicting'),
#  (75, 'depth'),
#  (76, 'deserves'),
#  (77, 'despite'),
#  (78, 'destroyed'),
#  (79, 'development'),
#  (80, 'director'),
#  (81, 'directorial'),
#  (82, 'dozen'),
#  (83, 'drama'),
#  (84, 'dubbed'),
#  (85, 'easy'),
#  (86, 'effect'),
#  (87, 'effective'),
#  (88, 'end'),
#  (89, 'engaging'),
#  (90, 'ever'),
#  (91, 'family'),
#  (92, 'fan'),
#  (93, 'film'),
#  (94, 'films'),
#  (95, 'find'),
#  (96, 'flicks'),
#  (97, 'follow'),
#  (98, 'follows'),
#  (99, 'formulaic'),
#  (100, 'friendly'),
#  (101, 'game'),
#  (102, 'genre'),
#  (103, 'given'),
#  (104, 'goes'),
#  (105, 'going'),
#  (106, 'golf'),
#  (107, 'grand'),
#  (108, 'greatest'),
#  (109, 'harry'),
#  (110, 'hats'),
#  (111, 'haunted'),
#  (112, 'hbo'),
#  (113, 'he'),
#  (114, 'heads'),
#  (115, 'horror'),
#  (116, 'hour'),
#  (117, 'humble'),
#  (118, 'images'),
#  (119, 'imagine'),
#  (120, 'job'),
#  (121, 'knack'),
#  (122, 'know'),
#  (123, 'london'),
#  (124, 'loved'),
#  (125, 'man'),
#  (126, 'miracle'),
#  (127, 'montage'),
#  (128, 'moves'),
#  (129, 'nature'),
#  (130, 'nice'),
#  (131, 'numbers'),
#  (132, 'once'),
#  (133, 'open'),
#  (134, 'opening'),
#  (135, 'painfully'),
#  (136, 'paxton'),
#  (137, 'period'),
#  (138, 'pick'),
#  (139, 'piece'),
#  (140, 'play'),
#  (141, 'players'),
#  (142, 'plot'),
#  (143, 'pressure'),
#  (144, 'proceedings'),
#  (145, 'promising'),
#  (146, 'propel'),
#  (147, 'psychological'),
#  (148, 'puts'),
#  (149, 'rain'),
#  (150, 'recently'),
#  (151, 'rises'),
#  (152, 'root'),
#  (153, 'set'),
#  (154, 'shows'),
#  (155, 'slowly'),
#  (156, 'sports'),
#  (157, 'starts'),
#  (158, 'story'),
#  (159, 'suits'),
#  (160, 'talent'),
#  (161, 'there'),
#  (162, 'things'),
#  (163, 'true'),
#  (164, 'turned'),
#  (165, 'unexpected'),
#  (166, 'version'),
#  (167, 'visually'),
#  (168, 'way'),
#  (169, 'young'),
#  (170, 'accepted'),
#  (171, 'actual'),
#  (172, 'although'),
#  (173, 'americans'),
#  (174, 'as'),
#  (175, 'attempts'),
#  (176, 'battles'),
#  (177, 'beauty'),
#  (178, 'best'),
#  (179, 'br'),
#  (180, 'break'),
#  (181, 'ceiling'),
#  (182, 'century'),
#  (183, 'characters'),
#  (184, 'childhood'),
#  (185, 'class'),
#  (186, 'competing'),
#  (187, 'creation'),
#  (188, 'depicted'),
#  (189, 'desire'),
#  (190, 'detract'),
#  (191, 'disney'),
#  (192, 'dream'),
#  (193, 'early'),
#  (194, 'ending'),
#  (195, 'english'),
#  (196, 'equal'),
#  (197, 'eyes'),
#  (198, 'father'),
#  (199, 'fought'),
#  (200, 'glass'),
#  (201, 'hard'),
#  (202, 'his'),
#  (203, 'historical'),
#  (204, 'history'),
#  (205, 'human'),
#  (206, 'inability'),
#  (207, 'issues'),
#  (208, 'knowledge'),
#  (209, 'liberties'),
#  (210, 'little'),
#  (211, 'mere'),
#  (212, 'moment'),
#  (213, 'mother'),
#  (214, 'parents'),
#  (215, 'photographed'),
#  (216, 'pleased'),
#  (217, 'pool'),
#  (218, 'pursue'),
#  (219, 'rise'),
#  (220, 'scenes'),
#  (221, 'sees'),
#  (222, 'site'),
#  (223, 'society'),
#  (224, 'son'),
#  (225, 'standing'),
#  (226, 'struggles'),
#  (227, 'table'),
#  (228, 'taken'),
#  (229, 'theme'),
#  (230, 'think'),
#  (231, 'upper'),
#  (232, 'value'),
#  (233, 'viewer'),
#  (234, 'work'),
#  (235, 'working'),
#  (236, 'written'),
#  (237, 'acting'),
#  (238, 'actors'),
#  (239, 'before'),
#  (240, 'charming'),
#  (241, 'cinematography'),
#  (242, 'contained'),
#  (243, 'contains'),
#  (244, 'delightful'),
#  (245, 'deserve'),
#  (246, 'expect'),
#  (247, 'fabulous'),
#  (248, 'high'),
#  (249, 'if'),
#  (250, 'incredibly'),
#  (251, 'lead'),
#  (252, 'makes'),
#  (253, 'marvelous'),
#  (254, 'moments'),
#  (255, 'movies'),
#  (256, 'preview'),
#  (257, 'realize'),
#  (258, 'recommend'),
#  (259, 'self'),
#  (260, 'sneak'),
#  (261, 'stands'),
#  (262, 'suspense'),
#  (263, 'sweet'),
#  (264, 'wo'),
#  (265, 'and'),
#  (266, 'anti'),
#  (267, 'but'),
#  (268, 'catholic'),
#  (269, 'clear'),
#  (270, 'deals'),
#  (271, 'delivers'),
#  (272, 'directing'),
#  (273, 'directly'),
#  (274, 'england'),
#  (275, 'establishment'),
#  (276, 'even'),
#  (277, 'excellent'),
#  (278, 'extra'),
#  (279, 'familiar'),
#  (280, 'fashioned'),
#  (281, 'favourite'),
#  (282, 'fighting'),
#  (283, 'fill'),
#  (284, 'final'),
#  (285, 'fine'),
#  (286, 'for'),
#  (287, 'franco'),
#  (288, 'heart'),
#  (289, 'highly'),
#  (290, 'irish'),
#  (291, 'josh'),
#  (292, 'kid'),
#  (293, 'maturity'),
#  (294, 'new'),
#  (295, 'nod'),
#  (296, 'old'),
#  (297, 'ordinary'),
#  (298, 'performance'),
#  (299, 'performances'),
#  (300, 'pleasures'),
#  (301, 'profound'),
#  (302, 'revelation'),
#  (303, 'scene'),
#  (304, 'sense'),
#  (305, 'slap'),
#  (306, 'steal'),
#  (307, 'stephen'),
#  (308, 'stick'),
#  (309, 'surprise'),
#  (310, 'sympathetic'),
#  (311, 'touches'),
#  (312, 'triumph'),
#  (313, 'us'),
#  (314, 'usual'),
#  (315, 'word'),
#  (316, 'year'),
#  (317, 'a'),
#  (318, 'adds'),
#  (319, 'appears'),
#  (320, 'art'),
#  (321, 'at'),
#  (322, 'award'),
#  (323, 'backdrop'),
#  (324, 'big'),
#  (325, 'boy'),
#  (326, 'britain'),
#  (327, 'conditions'),
#  (328, 'country'),
#  (329, 'courage'),
#  (330, 'direction'),
#  (331, 'displays'),
#  (332, 'editing'),
#  (333, 'example'),
#  (334, 'explores'),
#  (335, 'festival'),
#  (336, 'francis'),
#  (337, 'gave'),
#  (338, 'gets'),
#  (339, 'hilarious'),
#  (340, 'holes'),
#  (341, 'hope'),
#  (342, 'ill'),
#  (343, 'journey'),
#  (344, 'learn'),
#  (345, 'life'),
#  (346, 'lot'),
#  (347, 'moving'),
#  (348, 'odds'),
#  (349, 'past'),
#  (350, 'people'),
#  (351, 'picture'),
#  (352, 'pictures'),
#  (353, 'positive'),
#  (354, 'prepared'),
#  (355, 'remember'),
#  (356, 'respect'),
#  (357, 'rich'),
#  (358, 'short'),
#  (359, 'small'),
#  (360, 'spirit'),
#  (361, 'stars'),
#  (362, 'steals'),
#  (363, 'stunning'),
#  (364, 'takes'),
#  (365, 'terrible'),
#  (366, 'time'),
#  (367, 'truly'),
#  (368, 'unfolds'),
#  (369, 'use'),
#  (370, 'values'),
#  (371, 'web'),
#  (372, 'with'),
#  (373, 'wooden'),
#  (374, 'world'),
#  (375, 'years'),
#  (376, 'actually'),
#  (377, 'appear'),
#  (378, 'arms'),
#  (379, 'blow'),
#  (380, 'career'),
#  (381, 'cast'),
#  (382, 'casting'),
#  (383, 'christ'),
#  (384, 'come'),
#  (385, 'coming'),
#  (386, 'complex'),
#  (387, 'details'),
#  (388, 'developing'),
#  (389, 'device'),
#  (390, 'difficult'),
#  (391, 'drugs'),
#  (392, 'etc'),
#  (393, 'feel'),
#  (394, 'feeling'),
#  (395, 'flawed'),
#  (396, 'freedom'),
#  (397, 'getting'),
#  (398, 'hand'),
#  (399, 'happiness'),
#  (400, 'haunting'),
#  (401, 'head'),
#  (402, 'heavy'),
#  (403, 'hero'),
#  (404, 'hongsheng'),
#  (405, 'house'),
#  (406, 'it'),
#  (407, 'jesus'),
#  (408, 'jia'),
#  (409, 'lies'),
#  (410, 'lowest'),
#  (411, 'main'),
#  (412, 'maybe'),
#  (413, 'mean'),
#  (414, 'merely'),
#  (415, 'obviously'),
#  (416, 'parts'),
#  (417, 'point'),
#  (418, 'points'),
#  (419, 'reading'),
#  (420, 'recommended'),
#  (421, 'setting'),
#  (422, 'shown'),
#  (423, 'soundtrack'),
#  (424, 'stage'),
#  (425, 'superb'),
#  (426, 'ted'),
#  (427, 'they'),
#  (428, 'told'),
#  (429, 'transformation'),
#  (430, 'view'),
#  (431, 'vulnerable'),
#  (432, 'window'),
#  (433, 'wonder'),
#  (434, 'writing'),
#  (435, 'achievement'),
#  (436, 'answer'),
#  (437, 'aspect'),
#  (438, 'aspects'),
#  (439, 'certainly'),
#  (440, 'check'),
#  (441, 'cheesy'),
#  (442, 'chinese'),
#  (443, 'convincingly'),
#  (444, 'crap'),
#  (445, 'cultural'),
#  (446, 'culture'),
#  (447, 'definitely'),
#  (448, 'different'),
#  (449, 'disappointed'),
#  (450, 'drug'),
#  (451, 'familiarity'),
#  (452, 'fashion'),
#  (453, 'felt'),
#  (454, 'found'),
#  (455, 'interesting'),
#  (456, 'leave'),
#  (457, 'music'),
#  (458, 'note'),
#  (459, 'on'),
#  (460, 'original'),
#  (461, 'parent'),
#  (462, 'playing'),
#  (463, 'qualities'),
#  (464, 'questions'),
#  (465, 'relationships'),
#  (466, 'television'),
#  (467, 'unique'),
#  (468, 'whatever'),
#  (469, 'amazing'),
#  (470, 'angry'),
#  (471, 'bike'),
#  (472, 'care'),
#  (473, 'cry'),
#  (474, 'dad'),
#  (475, 'dark'),
#  (476, 'depression'),
#  (477, 'deserved'),
#  (478, 'documentary'),
#  (479, 'especially'),
#  (480, 'experience'),
#  (481, 'fact'),
#  (482, 'however'),
#  (483, 'like'),
#  (484, 'living'),
#  (485, 'many'),
#  (486, 'meaning'),
#  (487, 'oscar'),
#  (488, 'others'),
#  (489, 'overall'),
#  (490, 'plays'),
#  (491, 'portray'),
#  (492, 'problem'),
#  (493, 'quit'),
#  (494, 'real'),
#  (495, 'rides'),
#  (496, 'room'),
#  (497, 'searching'),
#  (498, 'shut'),
#  (499, 'struggling'),
#  (500, 'suffer'),
#  (501, 'understand'),
#  (502, 'walks'),
#  (503, 'wanna'),
#  (504, 'act'),
#  (505, 'acted'),
#  (506, 'acts'),
#  (507, 'additional'),
#  (508, 'all'),
#  (509, 'anger'),
#  (510, 'appeal'),
#  (511, 'arrive'),
#  (512, 'artist'),
#  (513, 'arts'),
#  (514, 'available'),
#  (515, 'back'),
#  (516, 'begin'),
#  (517, 'bloody'),
#  (518, 'blue'),
#  (519, 'board'),
#  (520, 'body'),
#  (521, 'boot'),
#  (522, 'bound'),
#  (523, 'bring'),
#  (524, 'buddy'),
#  (525, 'challenge'),
#  (526, 'chance'),
#  (527, 'change'),
#  (528, 'clichã'),
#  (529, 'cloud'),
#  (530, 'clumsy'),
#  (531, 'complete'),
#  (532, 'confusion'),
#  (533, 'connection'),
#  (534, 'contact'),
#  (535, 'control'),
#  (536, 'convincing'),
#  (537, 'cool'),
#  (538, 'crazed'),
#  (539, 'criticism'),
#  (540, 'current'),
#  (541, 'dancer'),
#  (542, 'darkness'),
#  (543, 'deal'),
#  (544, 'demands'),
#  (545, 'departure'),
#  (546, 'doors'),
#  (547, 'doubt'),
#  (548, 'drink'),
#  (549, 'drives'),
#  (550, 'effects'),
#  (551, 'emotionally'),
#  (552, 'escape'),
#  (553, 'evident'),
#  (554, 'exchange'),
#  (555, 'exposes'),
#  (556, 'face'),
#  (557, 'fake'),
#  (558, 'false'),
#  (559, 'far'),
#  (560, 'forever'),
#  (561, 'gained'),
#  (562, 'gender'),
#  (563, 'green'),
#  (564, 'guide'),
#  (565, 'guy'),
#  (566, 'hang'),
#  (567, 'help'),
#  (568, 'heroic'),
#  (569, 'home'),
#  (570, 'honesty'),
#  (571, 'hongshen'),
#  (572, 'hot'),
#  (573, 'humor'),
#  (574, 'humorous'),
#  (575, 'iconic'),
#  (576, 'identity'),
#  (577, 'in'),
#  (578, 'influence'),
#  (579, 'inmates'),
#  (580, 'integrity'),
#  (581, 'john'),
#  (582, 'kind'),
#  (583, 'knows'),
#  (584, 'lacking'),
#  (585, 'language'),
#  (586, 'legs'),
#  (587, 'lennon'),
#  (588, 'line'),
#  (589, 'locations'),
#  (590, 'lonely'),
#  (591, 'long'),
#  (592, 'loss'),
#  (593, 'mainly'),
#  (594, 'mary'),
#  (595, 'means'),
#  (596, 'mental'),
#  (597, 'metal'),
#  (598, 'mid'),
#  (599, 'mind'),
#  (600, 'money'),
#  (601, 'need'),
#  (602, 'needs'),
#  (603, 'nineties'),
#  (604, 'no'),
#  (605, 'not'),
#  (606, 'occurs'),
#  (607, 'offer'),
#  (608, 'opens'),
#  (609, 'order'),
#  (610, 'pain'),
#  (611, 'park'),
#  (612, 'peasant'),
#  (613, 'perfect'),
#  (614, 'personal'),
#  (615, 'phony'),
#  (616, 'picking'),
#  (617, 'poignant'),
#  (618, 'poster'),
#  (619, 'pre'),
#  (620, 'presence'),
#  (621, 'pride'),
#  (622, 'projects'),
#  (623, 'rage'),
#  (624, 'rare'),
#  (625, 'realistic'),
#  (626, 'recognizable'),
#  (627, 'reflect'),
#  (628, 'rehab'),
#  (629, 'released'),
#  (630, 'replies'),
#  (631, 'road'),
#  (632, 'roles'),
#  (633, 'romance'),
#  (634, 'romantic'),
#  (635, 'roots'),
#  (636, 'rural'),
#  (637, 's'),
#  (638, 'saving'),
#  (639, 'says'),
#  (640, 'separate'),
#  (641, 'sex'),
#  (642, 'shaking'),
#  (643, 'shallow'),
#  (644, 'showing'),
#  (645, 'sister'),
#  (646, 'sky'),
#  (647, 'slips'),
#  (648, 'so'),
#  (649, 'soap'),
#  (650, 'soon'),
#  (651, 'sounding'),
#  (652, 'space'),
#  (653, 'speaks'),
#  (654, 'specific'),
#  (655, 'speech'),
#  (656, 'start'),
#  (657, 'started'),
#  (658, 'stereotypes'),
#  (659, 'street'),
#  (660, 'struck'),
#  (661, 'stuff'),
#  (662, 'success'),
#  (663, 'sun'),
#  (664, 'talented'),
#  (665, 'telling'),
#  (666, 'term'),
#  (667, 'thinking'),
#  (668, 'till'),
#  (669, 'to'),
#  (670, 'treat'),
#  (671, 'trouble'),
#  (672, 'trust'),
#  (673, 'tv'),
#  (674, 'users'),
#  (675, 'videos'),
#  (676, 'violence'),
#  (677, 'violent'),
#  (678, 'walk'),
#  (679, 'wanted'),
#  (680, 'wrenching'),
#  (681, 'you'),
#  (682, 'youth'),
#  (683, 'away'),
#  (684, 'bed'),
#  (685, 'believe'),
#  (686, 'blew'),
#  (687, 'changed'),
#  (688, 'channel'),
#  (689, 'drawing'),
#  (690, 'earlier'),
#  (691, 'enjoy'),
#  (692, 'excitement'),
#  (693, 'give'),
#  (694, 'got'),
#  (695, 'guess'),
#  (696, 'hate'),
#  (697, 'having'),
#  (698, 'hell'),
#  (699, 'honest'),
#  (700, 'instead'),
#  (701, 'international'),
#  (702, 'leaves'),
#  (703, 'left'),
#  (704, 'lines'),
#  (705, 'love'),
#  (706, 'me'),
#  (707, 'obvious'),
#  (708, 'relate'),
#  (709, 'rules'),
#  (710, 'satellite'),
#  (711, 'saying'),
#  (712, 'stayed'),
#  (713, 'support'),
#  (714, 'thing'),
#  (715, 'three'),
#  (716, 'thumbs'),
#  (717, 'totally'),
#  (718, 'type'),
#  (719, 'usually'),
#  (720, 'wish'),
#  (721, 'agree'),
#  (722, 'alert'),
#  (723, 'attend'),
#  (724, 'attention'),
#  (725, 'awards'),
#  (726, 'bad'),
#  (727, 'choices'),
#  (728, 'comments'),
#  (729, 'deeply'),
#  (730, 'detail'),
#  (731, 'dylan'),
#  (732, 'every'),
#  (733, 'fortunate'),
#  (734, 'hoping'),
#  (735, 'innocence'),
#  (736, 'killed'),
#  (737, 'mesmerizing'),
#  (738, 'miller'),
#  (739, 'nominated'),
#  (740, 'production'),
#  (741, 'question'),
#  (742, 'screen'),
#  (743, 'sure'),
#  (744, 'throwing'),
#  (745, 'william'),
#  (746, 'america'),
#  (747, 'devotion'),
#  (748, 'feels'),
#  (749, 'foreign'),
#  (750, 'hold'),
#  (751, 'matter'),
#  (752, 'metaphor'),
#  (753, 'network'),
#  (754, 'opinion'),
#  (755, 'please'),
#  (756, 'poorly'),
#  (757, 'pure'),
#  (758, 'rough'),
#  (759, 'settings'),
#  (760, 'shape'),
#  (761, 'situations'),
#  (762, 'times'),
#  (763, 'trip'),
#  (764, 'underground'),
#  (765, 'wanting'),
#  (766, 'watch'),
#  (767, 'watched'),
#  (768, 'water'),
#  (769, 'which'),
#  (770, 'worth'),
#  (771, 'alcohol'),
#  (772, 'asian'),
#  (773, 'b'),
#  (774, 'elements'),
#  (775, 'fun'),
#  (776, 'gather'),
#  (777, 'guts'),
#  (778, 'hurt'),
#  (779, 'important'),
#  (780, 'loves'),
#  (781, 'painful'),
#  (782, 'person'),
#  (783, 'since'),
#  (784, 'surrounding'),
#  (785, 'touched'),
#  (786, 'touching'),
#  (787, 'watching'),
#  (788, 'what'),
#  (789, 'chick'),
#  (790, 'health'),
#  (791, 'including'),
#  (792, 'individuals'),
#  (793, 'institution'),
#  (794, 'my'),
#  (795, 'plus'),
#  (796, 'sorry'),
#  (797, 'stand'),
#  (798, 'typical'),
#  (799, 'unbelievable'),
#  (800, 'want'),
#  (801, 'wife'),
#  (802, 'beautiful'),
#  (803, 'because'),
#  (804, 'behavior'),
#  (805, 'bitter'),
#  (806, 'caught'),
#  (807, 'choose'),
#  (808, 'dragging'),
#  (809, 'draws'),
#  (810, 'drive'),
#  (811, 'easily'),
#  (812, 'eighties'),
#  (813, 'environment'),
#  (814, 'events'),
#  (815, 'facts'),
#  (816, 'guitar'),
#  (817, 'happen'),
#  (818, 'interested'),
#  (819, 'interviews'),
#  (820, 'late'),
#  (821, 'later'),
#  (822, 'making'),
#  (823, 'methods'),
#  (824, 'modern'),
#  (825, 'partly'),
#  (826, 'popular'),
#  (827, 'recommendation'),
#  (828, 'relationship'),
#  (829, 'river'),
#  (830, 'scenario'),
#  (831, 'somewhat'),
#  (832, 'strong'),
#  (833, 'struggle'),
#  (834, 'tone'),
#  (835, 'treats'),
#  (836, 'try'),
#  (837, 'we'),
#  (838, 'writer'),
#  (839, 'anyway'),
#  (840, 'apartment'),
#  (841, 'asylum'),
#  (842, 'blood'),
#  (843, 'brigitte'),
#  (844, 'came'),
#  (845, 'completely'),
#  (846, 'condition'),
#  (847, 'developed'),
#  (848, 'dull'),
#  (849, 'enjoyable'),
#  (850, 'escapes'),
#  (851, 'extremely'),
#  (852, 'filming'),
#  (853, 'frantic'),
#  (854, 'french'),
#  (855, 'group'),
#  (856, 'held'),
#  (857, 'highway'),
#  (858, 'horribly'),
#  (859, 'hunted'),
#  (860, 'jean'),
#  (861, 'lesbian'),
#  (862, 'lips'),
#  (863, 'look'),
#  (864, 'medical'),
#  (865, 'meets'),
#  (866, 'members'),
#  (867, 'memorable'),
#  (868, 'most'),
#  (869, 'nudity'),
#  (870, 'number'),
#  (871, 'offers'),
#  (872, 'office'),
#  (873, 'outside'),
#  (874, 'pace'),
#  (875, 'picks'),
#  (876, 'place'),
#  (877, 'plenty'),
#  (878, 'porn'),
#  (879, 'rollin'),
#  (880, 'sad'),
#  (881, 'similar'),
#  (882, 'slow'),
#  (883, 'star'),
#  (884, 'still'),
#  (885, 'stops'),
#  (886, 'town'),
#  (887, 'unfortunately'),
#  (888, 'vampire'),
#  (889, 'absence'),
#  (890, 'active'),
#  (891, 'actresses'),
#  (892, 'adult'),
#  (893, 'assistant'),
#  (894, 'atmospheric'),
#  (895, 'barely'),
#  (896, 'beautifully'),
#  (897, 'bernard'),
#  (898, 'bit'),
#  (899, 'blink'),
#  (900, 'block'),
#  (901, 'bridge'),
#  (902, 'budget'),
#  (903, 'cash'),
#  (904, 'catherine'),
#  (905, 'chaplin'),
#  (906, 'cinema'),
#  (907, 'claude'),
#  (908, 'comedian'),
#  (909, 'comes'),
#  (910, 'commercial'),
#  (911, 'composed'),
#  (912, 'context'),
#  (913, 'craft'),
#  (914, 'demanding'),
#  (915, 'describes'),
#  (916, 'devastating'),
#  (917, 'doctor'),
#  (918, 'driving'),
#  (919, 'eat'),
#  (920, 'effectively'),
#  (921, 'efforts'),
#  (922, 'elisabeth'),
#  (923, 'entirely'),
#  (924, 'escaped'),
#  (925, 'exceptional'),
#  (926, 'explicit'),
#  (927, 'exquisite'),
#  (928, 'fate'),
#  (929, 'feet'),
#  (930, 'fiction'),
#  (931, 'filmmaker'),
#  (932, 'flight'),
#  (933, 'fortunately'),
#  (934, 'future'),
#  (935, 'gary'),
#  (936, 'girl'),
#  (937, 'girls'),
#  (938, 'guard'),
#  (939, 'handle'),
#  (940, 'handled'),
#  (941, 'hands'),
#  (942, 'hardcore'),
#  (943, 'here'),
#  (944, 'hours'),
#  (945, 'include'),
#  (946, 'inevitable'),
#  (947, 'inevitably'),
#  (948, 'introduced'),
#  (949, 'jess'),
#  (950, 'k'),
#  (951, 'la'),
#  (952, 'largely'),
#  (953, 'leaving'),
#  (954, 'likes'),
#  (955, 'limited'),
#  (956, 'lose'),
#  (957, 'lunch'),
#  (958, 'member'),
#  (959, 'memories'),
#  (960, 'menacing'),
#  (961, 'miss'),
#  (962, 'mouth'),
#  (963, 'movements'),
#  (964, 'mysterious'),
#  (965, 'naked'),
#  (966, 'nearby'),
#  (967, 'notably'),
#  (968, 'occur'),
#  (969, 'paris'),
#  (970, 'particularly'),
#  (971, 'patients'),
#  (972, 'performer'),
#  (973, 'philippe'),
#  (974, 'physical'),
#  (975, 'picked'),
#  (976, 'porno'),
#  (977, 'present'),
#  (978, 'princess'),
#  (979, 'prior'),
#  (980, 'proved'),
#  (981, 'rachel'),
#  (982, 'rape'),
#  (983, 'rarely'),
#  (984, 'recall'),
#  (985, 'recognize'),
#  (986, 'relatively'),
#  (987, 'result'),
#  (988, 'reveals'),
#  (989, 'robert'),
#  (990, 'role'),
#  (991, 'sappy'),
#  (992, 'science'),
#  (993, 'section'),
#  (994, 'seeks'),
#  (995, 'served'),
#  (996, 'sheer'),
#  (997, 'shot'),
#  (998, 'sight'),
#  (999, 'single'),
#  ...]

# %%
len(thresholded_wordlist[0])
# Out:
# 59

# %% [markdown]
# ![image](https://i.imgur.com/f1uzTDZ.png)

# %% [markdown]
# # TODO
#
# * From the screenshot you can see the implementation of word-cooccurance matrix, based on the tokens from the dictionary, build a word-cooccurance matrix yourself which is $X$. Documentation of gensim [https://radimrehurek.com/gensim/corpora/dictionary.html]
# * Apply SVD on $X$
# * Reduce Dimension
#
# ![dimen_reduc](https://i.imgur.com/lezB870.png)
#
# * Here Richard is taking only top two dimensions of the vector $U$, recommended size is *50* for now.
#
# ![dimen_reduc_u](https://i.imgur.com/TA2Bmsq.png)
#
# * Now we can get a fixed size vector for each word.
#
# * Try to plot something similar based on the given dataset. In class we will try to implement a logistic regression classifier that can classify positive and negative reviews

# %%
import matplotlib.pyplot as plt

# %%
X = np.zeros((len(dictionary),len(dictionary)))
X.shape
# Out:
# (5464, 5464)
